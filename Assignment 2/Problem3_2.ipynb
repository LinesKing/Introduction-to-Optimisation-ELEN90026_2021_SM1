# %%
from numpy import array, dot
from qpsolvers import solve_qp

## Problem 3.(2)
# Define parameters
delta = (-0.1, 0., 0.1)
P = array([[2., -1.], [-1., 4.]])
q = array([[-1., 0.]]).reshape((2,))
G = array([[1., 2.], [1., -4.], [5., 76.]])

for i in range(len(delta)):
    for j in range(len(delta)):
        h = array([-2.+delta[i], -3.+delta[j], 1.]).reshape((3,))

        # Solve QP
        x = solve_qp(P, q, G, h)
        p = 1 / 2 * dot(dot(x, P), x) + dot(q, x)

        print("")
        print("delta1 = {}, delta2 = {}".format(delta[i], delta[j]))
        print("QP solution: x* = {}".format(x))
        print("QP solution: p* = {}".format(p))

for i in range(len(delta)):
    for j in range(len(delta)):
        pp = 8.2222 - 1.916*delta[i] - 3.4571*delta[j]

        print("")
        print("delta1 = {}, delta2 = {}".format(delta[i], delta[j]))
        print("QP solution: p^ = {}".format(pp))
# Out:
# delta1 = -0.1, delta2 = -0.1
# QP solution: x* = [-2.43333333  0.16666667]
# QP solution: p* = 8.815555555555555
#
# delta1 = -0.1, delta2 = 0.0
# QP solution: x* = [-2.4   0.15]
# QP solution: p* = 8.565000000000001
#
# delta1 = -0.1, delta2 = 0.1
# QP solution: x* = [-2.36666667  0.13333333]
# QP solution: p* = 8.31888888888889
#
# delta1 = 0.0, delta2 = -0.1
# QP solution: x* = [-2.4125    0.171875]
# QP solution: p* = 8.706386718750005
#
# delta1 = 0.0, delta2 = 0.0
# QP solution: x* = [-2.33333333  0.16666667]
# QP solution: p* = 8.222222222222221
#
# delta1 = 0.0, delta2 = 0.1
# QP solution: x* = [-2.3   0.15]
# QP solution: p* = 7.9799999999999995
#
# delta1 = 0.1, delta2 = -0.1
# QP solution: x* = [-2.4125    0.171875]
# QP solution: p* = 8.706386718749998
#
# delta1 = 0.1, delta2 = 0.0
# QP solution: x* = [-2.33333333  0.16666667]
# QP solution: p* = 8.222222222222221
#
# delta1 = 0.1, delta2 = 0.1
# QP solution: x* = [-2.25416667  0.16145833]
# QP solution: p* = 7.751525607638888
#
# delta1 = -0.1, delta2 = -0.1
# QP solution: p^ = 8.75951
#
# delta1 = -0.1, delta2 = 0.0
# QP solution: p^ = 8.4138
#
# delta1 = -0.1, delta2 = 0.1
# QP solution: p^ = 8.06809
#
# delta1 = 0.0, delta2 = -0.1
# QP solution: p^ = 8.567910000000001
#
# delta1 = 0.0, delta2 = 0.0
# QP solution: p^ = 8.2222
#
# delta1 = 0.0, delta2 = 0.1
# QP solution: p^ = 7.87649
#
# delta1 = 0.1, delta2 = -0.1
# QP solution: p^ = 8.376310000000002
#
# delta1 = 0.1, delta2 = 0.0
# QP solution: p^ = 8.030600000000002
#
# delta1 = 0.1, delta2 = 0.1
# QP solution: p^ = 7.684890000000001
